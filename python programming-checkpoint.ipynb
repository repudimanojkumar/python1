# %% [markdown]
# # python
# ## python
# ### python
# #### python
# ##### python
# ###### python
# 1. a
# 2. b
#      1. c
#      2. d
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Keywords:
# 1. Keywords are the reserved words in Python.
# 2. We cannot use a keyword as a variable name, function name or any other identifier.
# 3. They are used to define the syntax and structure of the Python language.
# 4. In Python, keywords are case sensitive.
# 5. There are 33 keywords in python
# 6. In this three of the first letter uppercase
# 7. Remaining all are lowercase

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# # Variables:

# %%
x=10.45
y=20
x+y
# Out:
# 30.45

# %% [markdown]
# x=100

# %%
type(x)
# Out:
# float

# %%
print(y)
type(y)
# Out:
# 20
# int

# %% [markdown]
# # input()and Print()

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(x)
# Out:
# 10.45

# %%
print("x")
# Out:
# x

# %%
print ("The value of x:",x)
# Out:
# The value of x: 10.45

# %%
y = input("enter y value")
print(y)
# Out:
# enter y value23
# 23

# %% [markdown]
# # Create 2 variables if the names age and name the candiate values from the users and displays

# %%
x=input("name of the candiate=")
y=int(input("enter the candidate age="))
print("my name is",x,"and my age is",y)
# Out:
# name of the candiate=manoj
# enter the candidate age=22
# my name is manoj and my age is 22

# %%
x=input("enter my name:")
y=int(input("enter my age:"))
print("my name is:",x,end=" ")
print("my age is:",y)
# Out:
# enter my name:manoj
# enter my age:22
# my name is: manoj my age is: 22

# %%
x=input("enter my name:")
Y=int(input("my age is:"))
print("my name is:",x,"my age is:",y,sep="\n")
# Out:
# enter my name:manoj
# my age is:22
# my name is:
# manoj
# my age is:
# 22

# %% [markdown]
# #  Indentations

# %%
if y>18:
    print("candiate is eligible")
    print("successfull")
    if y<20:
        print("y is 19 years")
    print("bye")
print("good bye")
# Out:
# candiate is eligible
# successfull
# bye
# good bye
